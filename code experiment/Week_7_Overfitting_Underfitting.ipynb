# %% [markdown]
# ### 1. Load Packages

# %%
import openai
import pandas as pd
import re
import json

# %% [markdown]
# ### 2. Load Tokens

# %%
openai.api_key = "To be filled"

# %% [markdown]
# ### 3. Load Data or Text

# %%
df1 = pd.read_csv('processed_60900_61899.csv')
df2 = pd.read_csv('processed_177000_177999.csv')

# %%
df1
# Out:
#      Unnamed: 0  GLOBAL_ID  LOCAL_ID  \
# 0         60900      60900      6555
# 1         60901      60901      6556
# 2         60902      60902      6557
# 3         60903      60903      6558
# 4         60904      60904      6559
# ..          ...        ...       ...
# 995       61895      61895      7550
# 996       61896      61896      7551
# 997       61897      61897      7552
# 998       61898      61898      7553
# 999       61899      61899      7554
#
#                                          processed_txt  \
# 0    we already have congestion pricing for taxis &...
# 1    an the best cannot be that much i am sorry htt...
# 2               handicap uber's is getting out of hand
# 3    bitchh i would calmly get in a cab laugh ill b...
# 4    take a cab. you are getting hepatitis walking ...
# ..                                                 ...
# 995  so...i confess ...i walked to target &amp; bou...
# 996                    uber, ferry, plane, train today
# 997  hi, i order some food about a hour ago and i h...
# 998  i was there. it was an uber. none of the other...
# 999  the best driver has 4.98 rating which is batsh...
#
#                           date      _date_      WoY
# 0    2021-07-09 00:02:34+00:00  2021-07-09  2021-27
# 1    2021-07-08 23:44:03+00:00  2021-07-08  2021-27
# 2    2021-07-08 23:40:10+00:00  2021-07-08  2021-27
# 3    2021-07-08 23:16:21+00:00  2021-07-08  2021-27
# 4    2021-07-08 23:15:04+00:00  2021-07-08  2021-27
# ..                         ...         ...      ...
# 995  2021-06-17 23:27:09+00:00  2021-06-17  2021-24
# 996  2021-06-17 23:00:01+00:00  2021-06-17  2021-24
# 997  2021-06-17 22:08:29+00:00  2021-06-17  2021-24
# 998  2021-06-17 21:54:38+00:00  2021-06-17  2021-24
# 999  2021-06-17 21:26:48+00:00  2021-06-17  2021-24
#
# [1000 rows x 7 columns]

# %%
df2
# Out:
#      Unnamed: 0  GLOBAL_ID  LOCAL_ID  \
# 0        177000     177000      7102
# 1        177001     177001      7103
# 2        177002     177002      7104
# 3        177003     177003      7105
# 4        177004     177004      7106
# ..          ...        ...       ...
# 995      177995     177995      8097
# 996      177996     177996      8098
# 997      177997     177997      8099
# 998      177998     177998      8100
# 999      177999     177999      8101
#
#                                          processed_txt  \
# 0    please kick japan out of my country they are s...
# 1    once i learned about correctional exercises an...
# 2                            empty train cars &gt;&gt;
# 3    that emerald parking lot is about 1 mile walk ...
# 4    that is going to take time, i need car by end ...
# ..                                                 ...
# 995  how about getting all trash off the sidewalk? ...
# 996  get trash off the sidewalk. trash corals in th...
# 997  people of philadelphia find trae young's hotel...
# 998  ring rain coming back for more and do not you ...
# 999  a tesla costs the same as any other new car i ...
#
#                           date      _date_      WoY
# 0    2021-11-26 13:17:13+00:00  2021-11-26  2021-47
# 1    2021-11-26 12:41:27+00:00  2021-11-26  2021-47
# 2    2021-11-26 12:22:52+00:00  2021-11-26  2021-47
# 3    2021-11-26 12:14:05+00:00  2021-11-26  2021-47
# 4    2021-11-26 11:48:54+00:00  2021-11-26  2021-47
# ..                         ...         ...      ...
# 995  2021-06-03 02:03:54+00:00  2021-06-03  2021-22
# 996  2021-06-03 02:00:17+00:00  2021-06-03  2021-22
# 997  2021-06-03 01:55:00+00:00  2021-06-03  2021-22
# 998  2021-06-03 01:40:50+00:00  2021-06-03  2021-22
# 999  2021-06-03 01:30:38+00:00  2021-06-03  2021-22
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### 4.Chain of thought

# %%
def generate_chain_of_thought(tweet):
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages = [
            {
                "role": "system",
                "content": "You are an AI specifically trained to extract travel experiences from tweets, focusing on the mode of transportation, the sentiment towards it, and the reasons behind the sentiment. It's crucial to maintain consistency in your analysis, avoiding assumptions not supported by the tweet's content (overfitting), yet also ensuring to provide as much detail as possible without defaulting to 'na' unless absolutely necessary (underfitting). Your responses should be in lowercase and adhere to the specified categories."
            },
            {
                "role": "user",
                "content": f"Analyze the tweet: '{tweet.lower()}'. Your goal is to clearly identify the travel experience it describes, focusing on these aspects:\n\n"
                   f"Given the tweet: \"{prepared_tweet}\" 1. What is the corresponding travel mode? (Train, subway, bus, bike, taxi, Uber, private car) 2. Is the user satisfied with the corresponding travel mode’s service? (Yes or No) 3. If not satisfied, what are the reasons behind?"
                   "Conclude with a concise, structured summary (keep this format for all your response) in JSON format, like this: "
                   "{\"travel_mode\": \"<inferred mode>\", \"sentiment\": \"<inferred sentiment>\", \"reasons\": \"<inferred reasons>\"}. Remember, consistency and adherence to the evidence presented in the tweet are key."
            }
        ],
        temperature=0.7,  # A slightly higher temperature for creativity in judgment
        max_tokens=250
    )
    content = response.choices[0].message.content if response.choices else "No response"
    return content

# %%
def process_tweet_and_generate_output(df):
    processed_data = []
    
    for index, row in df.iterrows():
        analysis_result_json = generate_chain_of_thought(row['processed_txt'])
        
        try:
            # Attempt to parse the JSON string
            analysis_result = json.loads(analysis_result_json)
        except json.JSONDecodeError:
            # If parsing fails, use default values
            analysis_result = {"travel_mode": "na", "sentiment": "neutral", "reasons": "Parsing error or invalid format in response."}
        
        # Extract and store the relevant information along with the GLOBAL_ID and original tweet
        processed_row = {
            "GLOBAL_ID": row['GLOBAL_ID'],
            "Tweet": row['processed_txt'],
            "Travel Mode": analysis_result.get('travel_mode', 'NA'),
            "Sentiment": analysis_result.get('sentiment', 'NA'),
            "Reasons": analysis_result.get('reasons', 'NA')
        }
        
        # Append the processed row to the list of processed data
        processed_data.append(processed_row)

    # Convert the processed data into a DataFrame
    return pd.DataFrame(processed_data)

# %% [markdown]
# ### 5.Outcome

# %% [markdown]
# **(1) df1: processed_60900_61899.csv**

# %%
# test
process_tweet_and_generate_output(df1.iloc[0:2])
# Out:
#    GLOBAL_ID                                              Tweet Travel Mode  \
# 0      60900  we already have congestion pricing for taxis &...         car
# 1      60901  an the best cannot be that much i am sorry htt...          na
#
#   Sentiment                                            Reasons
# 0  positive  congestion pricing for cars and trucks is inte...
# 1        na                                                 na

# %%
processed_df1 = process_tweet_and_generate_output(df1)
processed_df1.to_csv('result_df1_edit.csv', index=False)

# %%
processed_df1
# Out:
#      GLOBAL_ID                                              Tweet  \
# 0        60900  we already have congestion pricing for taxis &...
# 1        60901  an the best cannot be that much i am sorry htt...
# 2        60902             handicap uber's is getting out of hand
# 3        60903  bitchh i would calmly get in a cab laugh ill b...
# 4        60904  take a cab. you are getting hepatitis walking ...
# ..         ...                                                ...
# 995      61895  so...i confess ...i walked to target &amp; bou...
# 996      61896                    uber, ferry, plane, train today
# 997      61897  hi, i order some food about a hour ago and i h...
# 998      61898  i was there. it was an uber. none of the other...
# 999      61899  the best driver has 4.98 rating which is batsh...
#
#        Travel Mode Sentiment  \
# 0              car  positive
# 1               na        na
# 2              car  negative
# 3             taxi  positive
# 4             taxi  negative
# ..             ...       ...
# 995           uber  positive
# 996          plane   neutral
# 997  food delivery  negative
# 998           taxi   neutral
# 999            car  negative
#
#                                                Reasons
# 0    congestion pricing is intended to encourage pe...
# 1    The tweet does not provide clear information r...
# 2    The sentiment is negative towards Uber for the...
# 3    The author expresses a positive sentiment towa...
# 4    The sentiment towards taking a taxi is negativ...
# ..                                                 ...
# 995  The sentiment towards the Uber ride is positiv...
# 996  the tweet mentions various modes of transporta...
# 997                              delayed food delivery
# 998  the author mentions taking an Uber but doesn't...
# 999  the sentiment is negative due to the frustrati...
#
# [1000 rows x 5 columns]

# %%
processed_df1['Travel Mode'].value_counts().get('na', 0)
# Out:
# 253

# %% [markdown]
# **(2) df2: processed_177000_177999.csv**

# %%
processed_df2 = process_tweet_and_generate_output(df2)
processed_df2.to_csv('result_df2_edit.csv', index=False)

# %%
processed_df2
# Out:
#      GLOBAL_ID                                              Tweet Travel Mode  \
# 0       177000  please kick japan out of my country they are s...         car
# 1       177001  once i learned about correctional exercises an...         car
# 2       177002                          empty train cars &gt;&gt;       train
# 3       177003  that emerald parking lot is about 1 mile walk ...         car
# 4       177004  that is going to take time, i need car by end ...         car
# ..         ...                                                ...         ...
# 995     177995  how about getting all trash off the sidewalk? ...         car
# 996     177996  get trash off the sidewalk. trash corals in th...         car
# 997     177997  people of philadelphia find trae young's hotel...         car
# 998     177998  ring rain coming back for more and do not you ...         car
# 999     177999  a tesla costs the same as any other new car i ...         car
#
#     Sentiment                                            Reasons
# 0    negative  The sentiment towards the car transportation m...
# 1     neutral  The tweet metaphorically compares individuals ...
# 2    positive  The author expresses a positive sentiment towa...
# 3    negative  nightmare leaving the lot if you do not leave ...
# 4    positive  The author expresses the need for a car by the...
# ..        ...                                                ...
# 995  negative  The sentiment towards the car transportation m...
# 996  negative  The author expresses frustration with trash co...
# 997  negative  The sentiment is negative as the author expres...
# 998  positive  The sentiment towards the car is positive, lik...
# 999   neutral  The tweet discusses the cost comparison betwee...
#
# [1000 rows x 5 columns]

# %%
processed_df2['Travel Mode'].value_counts().get('na', 0)
# Out:
# 49

# %% [markdown]
# ### 6. Verfication

# %%
def verify_llm_output(tweet, travel_mode, sentiment, reasons):
    verification_prompt = f"""
    Based on the following tweet analysis:
    Tweet: {tweet}
    - Travel Mode: {travel_mode}
    - Sentiment: {sentiment}
    - Reasons: {reasons}

    Is this analysis 'correct' or 'incorrect'? Consider the relevance and accuracy of the travel mode, sentiment, and reasons given.
    """
    
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{
            "role": "system",
            "content": "You're a highly intelligent assistant. Please read the following analysis carefully and provide your verdict."
        }, {
            "role": "user",
            "content": verification_prompt
        }],
        temperature=0,  # Use 0 for deterministic output
        max_tokens=50
    )

    # Simplifying the response check
    text_response = response.choices[0].message.content.strip().lower()
    if "correct" in text_response:
        return "correct"
    elif "incorrect" in text_response:
        return "incorrect"
    else:
        return "undetermined"  # Use this if the response isn't clear

# %% [markdown]
# **(1) df1: processed_60900_61899.csv**

# %%
# test
verify_llm_output(processed_df1.iloc[0]['Tweet'],processed_df1.iloc[0]['Travel Mode'], processed_df1.iloc[0]['Sentiment'], processed_df1.iloc[0]['Reasons'])
# Out:
# 'correct'

# %%
processed_df1['Verification Result'] = processed_df1.apply(
    lambda row: verify_llm_output(row['Tweet'], row['Travel Mode'], row['Sentiment'], row['Reasons']), axis=1)

# %%
processed_df1
# Out:
#      GLOBAL_ID                                              Tweet  \
# 0        60900  we already have congestion pricing for taxis &...
# 1        60901  an the best cannot be that much i am sorry htt...
# 2        60902             handicap uber's is getting out of hand
# 3        60903  bitchh i would calmly get in a cab laugh ill b...
# 4        60904  take a cab. you are getting hepatitis walking ...
# ..         ...                                                ...
# 995      61895  so...i confess ...i walked to target &amp; bou...
# 996      61896                    uber, ferry, plane, train today
# 997      61897  hi, i order some food about a hour ago and i h...
# 998      61898  i was there. it was an uber. none of the other...
# 999      61899  the best driver has 4.98 rating which is batsh...
#
#        Travel Mode Sentiment  \
# 0              car  positive
# 1               na        na
# 2              car  negative
# 3             taxi  positive
# 4             taxi  negative
# ..             ...       ...
# 995           uber  positive
# 996          plane   neutral
# 997  food delivery  negative
# 998           taxi   neutral
# 999            car  negative
#
#                                                Reasons Verification Result
# 0    congestion pricing is intended to encourage pe...             correct
# 1    The tweet does not provide clear information r...             correct
# 2    The sentiment is negative towards Uber for the...             correct
# 3    The author expresses a positive sentiment towa...             correct
# 4    The sentiment towards taking a taxi is negativ...             correct
# ..                                                 ...                 ...
# 995  The sentiment towards the Uber ride is positiv...             correct
# 996  the tweet mentions various modes of transporta...             correct
# 997                              delayed food delivery             correct
# 998  the author mentions taking an Uber but doesn't...             correct
# 999  the sentiment is negative due to the frustrati...             correct
#
# [1000 rows x 6 columns]

# %%
processed_df1.to_csv('Week 7 result_60900_61899((after self-verification).csv', index=False)

# %%
processed_df1['Verification Result'].value_counts().get('correct', 0)
# Out:
# 999

# %% [markdown]
# **(2) df2: processed_177000_177999.csv**

# %%
processed_df2['Verification Result'] = processed_df2.apply(
    lambda row: verify_llm_output(row['Tweet'], row['Travel Mode'], row['Sentiment'], row['Reasons']), axis=1)

# %%
processed_df2
# Out:
#      GLOBAL_ID                                              Tweet Travel Mode  \
# 0       177000  please kick japan out of my country they are s...         car
# 1       177001  once i learned about correctional exercises an...         car
# 2       177002                          empty train cars &gt;&gt;       train
# 3       177003  that emerald parking lot is about 1 mile walk ...         car
# 4       177004  that is going to take time, i need car by end ...         car
# ..         ...                                                ...         ...
# 995     177995  how about getting all trash off the sidewalk? ...         car
# 996     177996  get trash off the sidewalk. trash corals in th...         car
# 997     177997  people of philadelphia find trae young's hotel...         car
# 998     177998  ring rain coming back for more and do not you ...         car
# 999     177999  a tesla costs the same as any other new car i ...         car
#
#     Sentiment                                            Reasons  \
# 0    negative  The sentiment towards the car transportation m...
# 1     neutral  The tweet metaphorically compares individuals ...
# 2    positive  The author expresses a positive sentiment towa...
# 3    negative  nightmare leaving the lot if you do not leave ...
# 4    positive  The author expresses the need for a car by the...
# ..        ...                                                ...
# 995  negative  The sentiment towards the car transportation m...
# 996  negative  The author expresses frustration with trash co...
# 997  negative  The sentiment is negative as the author expres...
# 998  positive  The sentiment towards the car is positive, lik...
# 999   neutral  The tweet discusses the cost comparison betwee...
#
#     Verification Result
# 0               correct
# 1               correct
# 2               correct
# 3               correct
# 4               correct
# ..                  ...
# 995             correct
# 996             correct
# 997             correct
# 998             correct
# 999             correct
#
# [1000 rows x 6 columns]

# %%
processed_df2.to_csv('Week 7 result_177000_177999(after self-verification).csv', index=False)

# %%
processed_df2['Verification Result'].value_counts().get('correct', 0)
# Out:
# 1000

# %% [markdown]
# ## 6. Output Evaluation

# %%
df2_res=pd.read_csv('Week 7 result_177000_177999(after self-verification).csv')
df2_res
# Out:
#      GLOBAL_ID                                              Tweet Travel Mode  \
# 0       177000  please kick japan out of my country they are s...         car
# 1       177001  once i learned about correctional exercises an...         car
# 2       177002                          empty train cars &gt;&gt;       train
# 3       177003  that emerald parking lot is about 1 mile walk ...         car
# 4       177004  that is going to take time, i need car by end ...         car
# ..         ...                                                ...         ...
# 995     177995  how about getting all trash off the sidewalk? ...         car
# 996     177996  get trash off the sidewalk. trash corals in th...         car
# 997     177997  people of philadelphia find trae young's hotel...         car
# 998     177998  ring rain coming back for more and do not you ...         car
# 999     177999  a tesla costs the same as any other new car i ...         car
#
#     Sentiment                                            Reasons  \
# 0    negative  The sentiment towards the car transportation m...
# 1     neutral  The comparison made in the tweet suggests a ne...
# 2    positive  The author expresses a positive sentiment towa...
# 3    negative  The primary mode of transportation is by car, ...
# 4     neutral  the tweet indicates a need for a car by the en...
# ..        ...                                                ...
# 995  negative  The sentiment towards the car is negative due ...
# 996  negative  The author expresses a negative sentiment towa...
# 997  negative  The sentiment expressed is negative as the twe...
# 998  positive  The sentiment towards the car ride seems posit...
# 999   neutral  The tweet discusses the cost of a Tesla compar...
#
#     Verification Result
# 0               correct
# 1               correct
# 2               correct
# 3               correct
# 4               correct
# ..                  ...
# 995             correct
# 996             correct
# 997             correct
# 998             correct
# 999             correct
#
# [1000 rows x 6 columns]

# %%
def analyze_data(df):
    # Analyze 'Travel Mode'
    unique_travel_modes = df['Travel Mode'].unique()
    print("Distinct outcomes for Travel Mode:", unique_travel_modes)

    number_of_distinct_travel_modes = df['Travel Mode'].nunique()
    print("Number of distinct outcomes for Travel Mode:", number_of_distinct_travel_modes)

    travel_mode_counts = df['Travel Mode'].value_counts()
    print("Counts for each distinct outcome in Travel Mode:", travel_mode_counts)

    # Analyze 'Sentiment'
    unique_sentiments = df['Sentiment'].unique()
    print("Distinct outcomes for Sentiment:", unique_sentiments)

    number_of_distinct_sentiments = df['Sentiment'].nunique()
    print("Number of distinct outcomes for Sentiment:", number_of_distinct_sentiments)

    sentiment_counts = df['Sentiment'].value_counts()
    print("Counts for each distinct outcome in Sentiment:", sentiment_counts)

    # Calculate various rates
    extraction_rate = len(df[~df['Travel Mode'].isin(['na', 'NA'])]) / len(df)
    satisfaction_rate = len(df[df['Sentiment'] == 'positive']) / len(df)
    self_verification_rate = len(df[df['Verification Result'] == 'correct']) / len(df)
    
    if 'Cross Verification Result' in df.columns:
        cross_verification_rate = len(df[df['Cross Verification Result'] == 'correct']) / len(df)
    else:
        cross_verification_rate = None
    
    return {
        'Extraction Rate': extraction_rate,
        'Satisfaction Rate': satisfaction_rate,
        'Self Verification Rate': self_verification_rate
    }

# %%
analyze_data(df2_res)
# Out:
# Distinct outcomes for Travel Mode: ['car' 'train' 'na' 'bike' 'taxi' 'walking' 'subway' 'scooter' 'flight'
#  nan 'helicopter' 'motorcycle' 'flying cars' 'skates' 'plane'
#  'pedestrians' 'transit' 'boat' 'bus' 'horse']
# Number of distinct outcomes for Travel Mode: 19
# Counts for each distinct outcome in Travel Mode: car            867
# na              48
# bike            18
# subway          18
# train           11
# walking          8
# scooter          6
# taxi             4
# plane            3
# bus              2
# helicopter       2
# flying cars      1
# boat             1
# pedestrians      1
# flight           1
# skates           1
# motorcycle       1
# transit          1
# horse            1
# Name: Travel Mode, dtype: int64
# Distinct outcomes for Sentiment: ['negative' 'neutral' 'positive' 'na' 'mixed' 'potentially negative'
#  'surprise']
# Number of distinct outcomes for Sentiment: 7
# Counts for each distinct outcome in Sentiment: negative                557
# positive                260
# neutral                 158
# na                       20
# mixed                     3
# surprise                  1
# potentially negative      1
# Name: Sentiment, dtype: int64
# {'Extraction Rate': 0.952,
#  'Satisfaction Rate': 0.26,
#  'Self Verification Rate': 1.0}
