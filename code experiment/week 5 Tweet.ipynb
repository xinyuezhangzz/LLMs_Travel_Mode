# %% [markdown]
# ### 1. Load Packages

# %%
import openai
import pandas as pd
import re

# %% [markdown]
# ### 2. Load Tokens

# %%
openai.api_key = "To be filled"

# %% [markdown]
# ### 3. Load Data or Text

# %%
df1 = pd.read_csv('processed_60900_61899.csv')
df2 = pd.read_csv('processed_177000_177999.csv')

# %%
df1
# Out:
#      Unnamed: 0  GLOBAL_ID  LOCAL_ID  \
# 0         60900      60900      6555
# 1         60901      60901      6556
# 2         60902      60902      6557
# 3         60903      60903      6558
# 4         60904      60904      6559
# ..          ...        ...       ...
# 995       61895      61895      7550
# 996       61896      61896      7551
# 997       61897      61897      7552
# 998       61898      61898      7553
# 999       61899      61899      7554
#
#                                          processed_txt  \
# 0    we already have congestion pricing for taxis &...
# 1    an the best cannot be that much i am sorry htt...
# 2               handicap uber's is getting out of hand
# 3    bitchh i would calmly get in a cab laugh ill b...
# 4    take a cab. you are getting hepatitis walking ...
# ..                                                 ...
# 995  so...i confess ...i walked to target &amp; bou...
# 996                    uber, ferry, plane, train today
# 997  hi, i order some food about a hour ago and i h...
# 998  i was there. it was an uber. none of the other...
# 999  the best driver has 4.98 rating which is batsh...
#
#                           date      _date_      WoY
# 0    2021-07-09 00:02:34+00:00  2021-07-09  2021-27
# 1    2021-07-08 23:44:03+00:00  2021-07-08  2021-27
# 2    2021-07-08 23:40:10+00:00  2021-07-08  2021-27
# 3    2021-07-08 23:16:21+00:00  2021-07-08  2021-27
# 4    2021-07-08 23:15:04+00:00  2021-07-08  2021-27
# ..                         ...         ...      ...
# 995  2021-06-17 23:27:09+00:00  2021-06-17  2021-24
# 996  2021-06-17 23:00:01+00:00  2021-06-17  2021-24
# 997  2021-06-17 22:08:29+00:00  2021-06-17  2021-24
# 998  2021-06-17 21:54:38+00:00  2021-06-17  2021-24
# 999  2021-06-17 21:26:48+00:00  2021-06-17  2021-24
#
# [1000 rows x 7 columns]

# %%
df2
# Out:
#      Unnamed: 0  GLOBAL_ID  LOCAL_ID  \
# 0        177000     177000      7102
# 1        177001     177001      7103
# 2        177002     177002      7104
# 3        177003     177003      7105
# 4        177004     177004      7106
# ..          ...        ...       ...
# 995      177995     177995      8097
# 996      177996     177996      8098
# 997      177997     177997      8099
# 998      177998     177998      8100
# 999      177999     177999      8101
#
#                                          processed_txt  \
# 0    please kick japan out of my country they are s...
# 1    once i learned about correctional exercises an...
# 2                            empty train cars &gt;&gt;
# 3    that emerald parking lot is about 1 mile walk ...
# 4    that is going to take time, i need car by end ...
# ..                                                 ...
# 995  how about getting all trash off the sidewalk? ...
# 996  get trash off the sidewalk. trash corals in th...
# 997  people of philadelphia find trae young's hotel...
# 998  ring rain coming back for more and do not you ...
# 999  a tesla costs the same as any other new car i ...
#
#                           date      _date_      WoY
# 0    2021-11-26 13:17:13+00:00  2021-11-26  2021-47
# 1    2021-11-26 12:41:27+00:00  2021-11-26  2021-47
# 2    2021-11-26 12:22:52+00:00  2021-11-26  2021-47
# 3    2021-11-26 12:14:05+00:00  2021-11-26  2021-47
# 4    2021-11-26 11:48:54+00:00  2021-11-26  2021-47
# ..                         ...         ...      ...
# 995  2021-06-03 02:03:54+00:00  2021-06-03  2021-22
# 996  2021-06-03 02:00:17+00:00  2021-06-03  2021-22
# 997  2021-06-03 01:55:00+00:00  2021-06-03  2021-22
# 998  2021-06-03 01:40:50+00:00  2021-06-03  2021-22
# 999  2021-06-03 01:30:38+00:00  2021-06-03  2021-22
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### 4.Chain of thought

# %%
def generate_chain_of_thought(tweet):
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": "You're an assistant skilled in understanding public transport experiences from tweets. Provide an analysis based on the tweet."
            },
            {
                "role": "user",
                "content": f"Given the tweet: '{tweet}', carefully analyze the content and context to determine the travel experience shared by the tweet's author. Considering that multiple modes of transportation might be mentioned, focus on identifying the primary mode the author is describing as their own experience. Follow these steps in your analysis:\n\n"
                           "1. **Identify the Primary Mode of Transportation:** Examine the tweet for mentions of travel modes (car, subway, bus, bike, taxi). Determine which mode the author specifically refers to as their own means of transportation, if directly mentioned or implied through context.\n"
                           "2. **Assess Sentiment:** Once the primary mode is identified, evaluate the sentiment the author expresses towards this mode of transportation—positive, negative, or neutral.\n"
                           "3. **Extract Reasons:** Delve into the reasons behind the author's sentiment towards the primary travel mode. Identify any specific experiences, aspects, or observations mentioned that influence their view.\n\n"
                           "Conclude your analysis with a structured summary of your findings in the following format: "
                           "{travel_mode: '<mode>', sentiment: '<sentiment>', reasons: '<reasons>'}."
            }
        ],
        temperature=0.5,
        max_tokens=250
    )
    # Ensure the response's 'content' is extracted correctly
    return response.choices[0].message.content if response.choices else "No response"

# %% [markdown]
# ### 5. parse answer

# %%
def parse_response(response_text):
    # Initialize default values
    travel_mode = 'NA'
    sentiment = 'neutral'
    reasons = 'No specific reasons given.'

    # Use regular expressions to extract the data
    try:
        travel_mode_match = re.search(r"travel_mode:\s*'([^']*)'", response_text)
        sentiment_match = re.search(r"sentiment:\s*'([^']*)'", response_text)
        reasons_match = re.search(r"reasons:\s*'([^']*)'", response_text)

        if travel_mode_match:
            travel_mode = travel_mode_match.group(1)
        if sentiment_match:
            sentiment = sentiment_match.group(1)
        if reasons_match:
            reasons = reasons_match.group(1)
    except Exception as e:
        print(f"Error parsing response: {e}")
        # Fallback to default values if parsing fails

    return travel_mode, sentiment, reasons

# %% [markdown]
# ### 5.Outcome

# %% [markdown]
# **(1) df1: processed_60900_61899.csv**

# %%
# test
tweet = df1.iloc[0]['processed_txt']
response_text = generate_chain_of_thought(tweet)
travel_mode, sentiment, reasons = parse_response(response_text)
travel_mode, sentiment, reasons
# Out:
# ('NA', 'neutral', 'No specific reasons given.')

# %%
df1_res = pd.DataFrame(columns=['Tweet', 'Travel Mode', 'Sentiment', 'Reasons'])

# Iterate through the original DataFrame
for index, row in df1.iterrows():
    tweet = row['processed_txt']  # Assuming 'processed_txt' contains the tweet text
    response_text = generate_chain_of_thought(tweet)
    travel_mode, sentiment, reasons = parse_response(response_text)
    
    # Append the results to the new DataFrame
    df1_res = df1_res.append({'Tweet': tweet, 'Travel Mode': travel_mode, 'Sentiment': sentiment, 'Reasons': reasons}, ignore_index=True)

# Save the new DataFrame to a new CSV file
df1_res.to_csv('result_df1.csv', index=False)

# %%
df1_res
# Out:
#                                                  Tweet  \
# 0    we already have congestion pricing for taxis &...
# 1    an the best cannot be that much i am sorry htt...
# 2               handicap uber's is getting out of hand
# 3    bitchh i would calmly get in a cab laugh ill b...
# 4    take a cab. you are getting hepatitis walking ...
# ..                                                 ...
# 995  so...i confess ...i walked to target &amp; bou...
# 996                    uber, ferry, plane, train today
# 997  hi, i order some food about a hour ago and i h...
# 998  i was there. it was an uber. none of the other...
# 999  the best driver has 4.98 rating which is batsh...
#
#                                            Travel Mode            Sentiment  \
# 0                                                  car             negative
# 1    Public Transportation (Potentially Bus or Subway)              neutral
# 2                                                 Uber             negative
# 3                                                 taxi             negative
# 4                                             cab/taxi             negative
# ..                                                 ...                  ...
# 995                                               Uber             positive
# 996                                              train              neutral
# 997                              Food delivery service             Negative
# 998                                               Uber  Surprised/Disbelief
# 999                                                car             negative
#
#                                                Reasons
# 0    The author expresses a negative sentiment towa...
# 1                           No specific reasons given.
# 2    Possible reasons for the negative sentiment in...
# 3    The author expresses a negative sentiment towa...
# 4    The author expresses a negative sentiment towa...
# ..                                                 ...
# 995  The author found Uber convenient and necessary...
# 996                                         The author
# 997  The author expresses frustration about not hav...
# 998                                         The author
# 999  The author expresses a negative sentiment towa...
#
# [1000 rows x 4 columns]

# %% [markdown]
# **(2) df2: processed_177000_177999.csv**

# %%
df2_res = pd.DataFrame(columns=['Tweet', 'Travel Mode', 'Sentiment', 'Reasons'])

# Iterate through the original DataFrame
for index, row in df2.iterrows():
    tweet = row['processed_txt']  # Assuming 'processed_txt' contains the tweet text
    response_text = generate_chain_of_thought(tweet)
    travel_mode, sentiment, reasons = parse_response(response_text)
    
    # Append the results to the new DataFrame
    df2_res = df2_res.append({'Tweet': tweet, 'Travel Mode': travel_mode, 'Sentiment': sentiment, 'Reasons': reasons}, ignore_index=True)

# Save the new DataFrame to a new CSV file
df2_res.to_csv('result_df2.csv', index=False)

# %%
df2_res
# Out:
#                                                  Tweet     Travel Mode  \
# 0    please kick japan out of my country they are s...             car
# 1    once i learned about correctional exercises an...  Not Applicable
# 2                            empty train cars &gt;&gt;           train
# 3    that emerald parking lot is about 1 mile walk ...     shuttle bus
# 4    that is going to take time, i need car by end ...             car
# ..                                                 ...             ...
# 995  how about getting all trash off the sidewalk? ...             car
# 996  get trash off the sidewalk. trash corals in th...             car
# 997  people of philadelphia find trae young's hotel...             car
# 998  ring rain coming back for more and do not you ...             car
# 999  a tesla costs the same as any other new car i ...     Car (Tesla)
#
#           Sentiment                                            Reasons
# 0          negative  The author expresses negative sentiment toward...
# 1    Not Applicable               The tweet focuses more on the author
# 2          positive  The author enjoys the comfort and peace of hav...
# 3          negative  The author expresses a negative sentiment towa...
# 4           neutral  The author expresses a practical need for a ca...
# ..              ...                                                ...
# 995        negative  Frustration with trash on the sidewalk and pri...
# 996        negative  The author is frustrated with the lack of spac...
# 997        negative  The author expresses frustration and annoyance...
# 998        positive  The author expresses a positive sentiment towa...
# 999         Neutral                         No specific reasons given.
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## 6.  Output Evaluation

# %%
df1_res = pd.read_csv('result_df1.csv')
df1
# Out:
#                                                  Tweet  \
# 0    we already have congestion pricing for taxis &...
# 1    an the best cannot be that much i am sorry htt...
# 2               handicap uber's is getting out of hand
# 3    bitchh i would calmly get in a cab laugh ill b...
# 4    take a cab. you are getting hepatitis walking ...
# ..                                                 ...
# 995  so...i confess ...i walked to target &amp; bou...
# 996                    uber, ferry, plane, train today
# 997  hi, i order some food about a hour ago and i h...
# 998  i was there. it was an uber. none of the other...
# 999  the best driver has 4.98 rating which is batsh...
#
#                                            Travel Mode            Sentiment  \
# 0                                                  car             negative
# 1    Public Transportation (Potentially Bus or Subway)              neutral
# 2                                                 Uber             negative
# 3                                                 taxi             negative
# 4                                             cab/taxi             negative
# ..                                                 ...                  ...
# 995                                               Uber             positive
# 996                                              train              neutral
# 997                              Food delivery service             Negative
# 998                                               Uber  Surprised/Disbelief
# 999                                                car             negative
#
#                                                Reasons
# 0    The author expresses a negative sentiment towa...
# 1                           No specific reasons given.
# 2    Possible reasons for the negative sentiment in...
# 3    The author expresses a negative sentiment towa...
# 4    The author expresses a negative sentiment towa...
# ..                                                 ...
# 995  The author found Uber convenient and necessary...
# 996                                         The author
# 997  The author expresses frustration about not hav...
# 998                                         The author
# 999  The author expresses a negative sentiment towa...
#
# [1000 rows x 4 columns]

# %%
def analyze_data(df):
    # Analyze 'Travel Mode'
    unique_travel_modes = df['Travel Mode'].unique()
    print("Distinct outcomes for Travel Mode:", unique_travel_modes)

    number_of_distinct_travel_modes = df['Travel Mode'].nunique()
    print("Number of distinct outcomes for Travel Mode:", number_of_distinct_travel_modes)

    travel_mode_counts = df['Travel Mode'].value_counts()
    print("Counts for each distinct outcome in Travel Mode:", travel_mode_counts)

    # Analyze 'Sentiment'
    unique_sentiments = df['Sentiment'].unique()
    print("Distinct outcomes for Sentiment:", unique_sentiments)

    number_of_distinct_sentiments = df['Sentiment'].nunique()
    print("Number of distinct outcomes for Sentiment:", number_of_distinct_sentiments)

    sentiment_counts = df['Sentiment'].value_counts()
    print("Counts for each distinct outcome in Sentiment:", sentiment_counts)

    # Calculate various rates
    extraction_rate = len(df[~df['Travel Mode'].isin(['na', 'NA','N/A'])]) / len(df)
    satisfaction_rate = len(df[df['Sentiment'] == 'positive']) / len(df)
    
    return {
        'Extraction Rate': extraction_rate,
        'Satisfaction Rate': satisfaction_rate,
    }

# %%
df1_res = pd.read_csv('result_df1.csv')
df1_res
# Out:
#                                                  Tweet  \
# 0    we already have congestion pricing for taxis &...
# 1    an the best cannot be that much i am sorry htt...
# 2               handicap uber's is getting out of hand
# 3    bitchh i would calmly get in a cab laugh ill b...
# 4    take a cab. you are getting hepatitis walking ...
# ..                                                 ...
# 995  so...i confess ...i walked to target &amp; bou...
# 996                    uber, ferry, plane, train today
# 997  hi, i order some food about a hour ago and i h...
# 998  i was there. it was an uber. none of the other...
# 999  the best driver has 4.98 rating which is batsh...
#
#                                            Travel Mode            Sentiment  \
# 0                                                  car             negative
# 1    Public Transportation (Potentially Bus or Subway)              neutral
# 2                                                 Uber             negative
# 3                                                 taxi             negative
# 4                                             cab/taxi             negative
# ..                                                 ...                  ...
# 995                                               Uber             positive
# 996                                              train              neutral
# 997                              Food delivery service             Negative
# 998                                               Uber  Surprised/Disbelief
# 999                                                car             negative
#
#                                                Reasons
# 0    The author expresses a negative sentiment towa...
# 1                           No specific reasons given.
# 2    Possible reasons for the negative sentiment in...
# 3    The author expresses a negative sentiment towa...
# 4    The author expresses a negative sentiment towa...
# ..                                                 ...
# 995  The author found Uber convenient and necessary...
# 996                                         The author
# 997  The author expresses frustration about not hav...
# 998                                         The author
# 999  The author expresses a negative sentiment towa...
#
# [1000 rows x 4 columns]

# %%
analyze_data(df1_res)
# Out:
# Distinct outcomes for Travel Mode: ['car' 'Public Transportation (Potentially Bus or Subway)' 'Uber' 'taxi'
#  'cab/taxi' 'Electric Vehicle/Car' 'cab' 'Lyft car service'
#  'Subway (Washington D.C. Metro)' 'Water-based transportation'
#  'Subway/Bus' 'bus' 'cabs and ubers' 'taxi/rideshare service' 'Lyft'
#  'yellow cab' 'Ride-sharing service (e.g., Uber, Lyft)' 'bike' 'Taxi'
#  'cycling' 'delivery service' 'Air travel (AirIndia)' 'Not applicable'
#  'N/A (related to anime series)' 'Taxi/Ride-sharing service'
#  'New York City public transportation' 'flight'
#  'Public Transport (implied)' 'Not Applicable' nan 'Lyft (car)'
#  'Various modes while drunk' 'Walking/Biking'
#  'Food delivery/takeout service' 'food delivery service'
#  'cabs or taxi services' 'taxi cabs' 'preferred mode of transportation'
#  'train (Metro North)' 'bus/train' 'driver' 'food delivery'
#  'betting on future bets for sports events' 'taxis' 'unspecified'
#  'airplane' 'Car' 'Not specified'
#  'anvil (potentially referring to a transportation service or system)'
#  'walking' 'Tesla car' 'Citibike' 'taxi/cab' 'Renting a car'
#  'taxi/ride-sharing service' 'Lyft (ride-sharing)' 'drone delivery'
#  'ride-hailing service' 'Ride-hailing service'
#  'public transport (subway or bus)' 'Ridesharing/Taxi (Lyft)' 'flying'
#  'not specified' 'ride-sharing services (Lyft)'
#  'Taxi/Ride-sharing services'
#  'Public Transportation (potentially bus or train)'
#  'ridesharing service (Uber/Lyft)'
#  'Food delivery service (e.g., DoorDash)' 'subway'
#  'ride-sharing service (e.g., Uber, Lyft)' 'Public Transportation in NYC'
#  'ride-sharing service (Lyft)' 'unknown' 'Car/Taxi'
#  'public transportation' 'undefined' 'mini van'
#  'public transport (implied)' 'Airport/Transit Complex' 'N/A (Guidance)'
#  'walking to the train station' 'Lyft (ridesharing)'
#  'Uber (ride-sharing service)' 'cab ride' 'ride-sharing service or taxi'
#  'Food Delivery Service' 'Car services (taxis/traditional car services)'
#  'Didi (ride-hailing service)' 'round trip' 'unclear'
#  'public transportation (bus)' 'bus/subway'
#  'public transportation (subway)' 'undisclosed' 'car (implied)'
#  'Taxi/Rideshare' 'public transport' 'plane' 'Ride-sharing/TNC service'
#  'food delivery service (e.g., eats courier)'
#  'rideshare service (e.g., Uber, Lyft)' 'public transport/walking'
#  'Food delivery service (car/bike)'
#  'Public Transportation (Bus/Shared Ride Service)' 'revel taxi service'
#  'driving' 'ridesharing (Lyft)' 'Ride-sharing (Uber and Lyft)'
#  'Ride-sharing service/taxi' 'Taxi (Yellow Cab)' 'Networking/Connections'
#  'Various modes (car, public transport, biking, walking)' 'car/taxi'
#  'pool' 'Food delivery services' 'Train/Bus' 'Toyota Camry hybrid'
#  'stock market trading' 'cab (taxi)'
#  'ride-hailing service (e.g., Uber, Lyft)' 'Walking' 'public transit'
#  'Tesla (electric car)' 'yellow cabs' 'Uber (ride-sharing)'
#  'Public transport (implied)' 'ride-sharing service'
#  'Ride-sharing service (e.g., Uber or Lyft)' 'N/A (Restaurant Visit)'
#  'Personal/Public Transportation for social outings' 'biking'
#  'Public transportation (MBTA and commuter rail)' 'Ride Service' 'train'
#  'Bus' 'Air Travel'
#  'Ride-sharing/Taxi/Public Transportation with Surge Pricing'
#  'Car or Personal Vehicle' 'Bus (B65)' 'Public Transport'
#  'driving (as an independent contractor)'
#  'Public Transportation (potentially bus, train, or taxi)' 'NYC subway'
#  'Public transport (bus and train)' 'Taxi/Ride-sharing Service'
#  'Walking or Public Transport' 'Ride-hailing services (Uber and Lyft)'
#  'Public Transportation (Bus/Train/Subway)' 'cab rides' 'Megabus'
#  'UberGreen' 'car (Lyft)' 'ambulance' 'bus or train'
#  'Train (Jersey Transit)' 'car (hitchhiking)' 'taxis in NYC'
#  'Ride-sharing service' 'Cab' 'public transport service/application'
#  'public transport (train or bus)' 'Virtual/Digital Platform'
#  'N/A - likely related to a swimming pool'
#  'driving in Istanbul during rush hour'
#  'Paid transportation (e.g., taxis, ride-sharing)' 'Taxis'
#  'public transportation (bus/subway)'
#  'Public transport (likely bus or train)' 'bike (Citibike)'
#  'community-provided rides' 'Unspecified' 'Bike'
#  'online transportation service' 'e-bike' 'Public Transport (Bus/Subway)'
#  'Taxi/Rideshare Service' 'not applicable' 'ride' 'ridesharing service'
#  'Driving' 'Laughlin Water Taxi' 'vehicle' 'trains'
#  'Subway/Bus (Public Transport)' 'Subjective/Not Specified' 'metro'
#  'driving (ride-sharing service)' 'Online financial transaction service'
#  'Lyft (ride-hailing service)' 'public transportation (likely subway)'
#  'Tesla taxi' 'Flight/Train/Bus' 'UberXL' 'Public Transport (Bus/Train)'
#  'Food delivery service' 'driving (car)'
#  'Personal vehicle or ride-sharing service' 'ride-sharing service (car)'
#  'Air travel'
#  'Public Transportation (potentially bus or shared ride service)'
#  'ride-sharing apps' 'Car/Bus' 'rewards program for food delivery service'
#  'Ride-sharing service (e.g., Uber/Lyft)'
#  'public transport/taxi/ride-sharing service'
#  'eats driver (food delivery service)' 'Food Delivery Services' 'airline'
#  'Public Transport (e.g., bus, train, subway)' 'Ola Cabs' 'boat taxi'
#  'banking/financial services' 'ride-sharing services (e.g., Uber, Lyft)'
#  'rideshare (eats driver)' 'Public Transport (Subway/Bus)'
#  'Taxi/Ride-sharing' 'luxurious mode of transportation'
#  'ridesharing services (taxi/Uber)' 'Ride-sharing services (Uber, Lyft)'
#  'For-Hire Vehicle (FHV) industry' 'Public Transportation (implied)'
#  'Food delivery service (implied car or bike)' 'Navigation application'
#  'yellow and green cabs' 'N/A (relying on best friend for transportation)'
#  'Public transport' 'dollar van'
#  'fast drivers (implied as taxi or rideshare)'
#  'food delivery service (The Best Eats)'
#  'Ride-hailing services (e.g., Uber, Lyft)' 'local cabs'
#  'not directly mentioned' 'ride service (such as Uber or Lyft)'
#  'Food delivery' 'Public transport (potentially subway, bus, or train)'
#  'ride service/taxi' 'Online transactions/e-commerce services'
#  'banking/financial system' 'N/A (leisure/recreational activity)' 'eBike'
#  'public transportation (subway or bus)' 'NFT transactions'
#  'Citibike e-bikes' 'black cab' 'Foot/Car' 'Car/Private Vehicle'
#  'Public Transportation' 'ride-sharing (Lyft)' 'food delivery (best eats)'
#  'on-demand scooters' 'Sky Taxis' 'Driver (Car)'
#  'Taxi/Ride-hailing service' 'Lyft (ride-hailing)' 'cars'
#  'application for transport service'
#  'public transport (e.g., subway, bus, taxi)' 'chartered jets'
#  'green cabs' 'Walking/Biking/Driving']
# Number of distinct outcomes for Travel Mode: 259
# Counts for each distinct outcome in Travel Mode: car                                       218
# taxi                                      119
# Uber                                       29
# Lyft                                       27
# Taxi                                       25
#                                          ...
# driving (as an independent contractor)      1
# Taxi/Ride-sharing Service                   1
# Water-based transportation                  1
# Tesla (electric car)                        1
# public transportation (subway or bus)       1
# Name: Travel Mode, Length: 259, dtype: int64
# Distinct outcomes for Sentiment: ['negative' 'neutral' 'Negative' 'Positive' 'positive' 'Neutral'
#  'slightly negative' 'Negative/Uncertain' 'negative/reluctant'
#  'Not determinable' 'nostalgic/reflective' 'Neutral/Positive'
#  'mixed (uncertain/discomfort)' 'slightly negative/uncertain'
#  'Negative/surprised' 'neutral/curious' 'neutral/positive'
#  'Negative/Concerned' 'frustration' 'ambiguous' 'neutral/humorous'
#  'potentially negative' 'mixed' 'extremely negative' 'Negative/Neutral'
#  'Negative/Confused' 'Nostalgic/Wistful' 'Playful and mischievous'
#  'Surprise/Astonishment' 'slightly negative/neutral' 'Mixed'
#  'Neutral (leaning slightly positive)' 'Nostalgic'
#  'Neutral to slightly negative' 'Boastful and dismissive'
#  'potentially positive' 'somewhat negative' 'somewhat positive'
#  'neutral to slightly positive' 'surprised/amused' nan
#  'Slightly negative/disappointed' 'Negative/frustrated' 'Neutral/Negative'
#  'Slightly negative/conflicted' 'Mixed (curiosity and frustration)'
#  'curious' 'slightly negative/mixed' 'neutral/negative'
#  'negative/uncertain' 'Slightly negative' 'frustrated'
#  'Neutral to Slightly Positive' 'Reflective/Emotional' 'confusion'
#  'Surprised/Disbelief']
# Number of distinct outcomes for Sentiment: 55
# Counts for each distinct outcome in Sentiment: negative                               430
# Negative                               148
# positive                               147
# neutral                                141
# Positive                                42
# Neutral                                 35
# slightly negative                        3
# extremely negative                       2
# Negative/Confused                        2
# Not determinable                         2
# Neutral/Positive                         2
# potentially positive                     2
# somewhat positive                        1
# confusion                                1
# Slightly negative                        1
# curious                                  1
# Slightly negative/conflicted             1
# frustrated                               1
# Negative/Uncertain                       1
# Nostalgic                                1
# Nostalgic/Wistful                        1
# nostalgic/reflective                     1
# Neutral to slightly negative             1
# neutral/humorous                         1
# Playful and mischievous                  1
# slightly negative/mixed                  1
# Negative/frustrated                      1
# somewhat negative                        1
# neutral/positive                         1
# Negative/Concerned                       1
# neutral/negative                         1
# potentially negative                     1
# mixed (uncertain/discomfort)             1
# Surprised/Disbelief                      1
# slightly negative/uncertain              1
# neutral/curious                          1
# ambiguous                                1
# frustration                              1
# neutral to slightly positive             1
# Neutral/Negative                         1
# Negative/surprised                       1
# slightly negative/neutral                1
# Mixed (curiosity and frustration)        1
# Reflective/Emotional                     1
# negative/uncertain                       1
# Slightly negative/disappointed           1
# negative/reluctant                       1
# Mixed                                    1
# Neutral (leaning slightly positive)      1
# Neutral to Slightly Positive             1
# surprised/amused                         1
# Surprise/Astonishment                    1
# Negative/Neutral                         1
# Boastful and dismissive                  1
# mixed                                    1
# Name: Sentiment, dtype: int64
# {'Extraction Rate': 1.0, 'Satisfaction Rate': 0.147}
