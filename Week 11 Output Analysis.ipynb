# %% [markdown]
# ### 1. Load Packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### 2. Load Data or Text

# %%
df1 = pd.read_csv('Week 11 result_60900_61899(after cross-verification).csv',)
df2 = pd.read_csv('Week 11 result_177000_177999(after cross-verification).csv')
df1_base = pd.read_csv('Week 11 result_60900_61899(baseline).csv')
df2_base = pd.read_csv('Week 11 result_177000_177999(baseline).csv')

# %%
df1
# Out:
#      GLOBAL_ID                                              Tweet Travel Mode  \
# 0        60900  we already have congestion pricing for taxis &...         car
# 1        60901  an the best cannot be that much i am sorry htt...          na
# 2        60902             handicap uber's is getting out of hand        uber
# 3        60903  bitchh i would calmly get in a cab laugh ill b...        taxi
# 4        60904  take a cab. you are getting hepatitis walking ...        taxi
# ..         ...                                                ...         ...
# 995      61895  so...i confess ...i walked to target &amp; bou...        uber
# 996      61896                    uber, ferry, plane, train today          na
# 997      61897  hi, i order some food about a hour ago and i h...          na
# 998      61898  i was there. it was an uber. none of the other...        uber
# 999      61899  the best driver has 4.98 rating which is batsh...         car
#
# ...

# %%
df2
# Out:
#      GLOBAL_ID                                              Tweet Travel Mode  \
# 0       177000  please kick japan out of my country they are s...          na
# 1       177001  once i learned about correctional exercises an...          na
# 2       177002                          empty train cars &gt;&gt;      subway
# 3       177003  that emerald parking lot is about 1 mile walk ...          na
# 4       177004  that is going to take time, i need car by end ...         car
# ..         ...                                                ...         ...
# 995     177995  how about getting all trash off the sidewalk? ...         car
# 996     177996  get trash off the sidewalk. trash corals in th...         car
# 997     177997  people of philadelphia find trae young's hotel...         car
# 998     177998  ring rain coming back for more and do not you ...         car
# 999     177999  a tesla costs the same as any other new car i ...         car
#
# ...

# %% [markdown]
# ### 3. Output Analysis - Data

# %% [markdown]
# #### (1) DF1: 60900_61899

# %%
# Find and print unique travel modes
unique_travel_modes1 = df1['Travel Mode'].unique()
print("Distinct outcomes for Travel Mode:", unique_travel_modes1)

# Count and print the number of unique travel modes
number_of_distinct_travel_modes1 = df1['Travel Mode'].nunique()
print("Number of distinct outcomes for Travel Mode:", number_of_distinct_travel_modes1)

# Print the counts of each travel mode
travel_mode_counts1 = df1['Travel Mode'].value_counts()
print("Counts for each distinct outcome in Travel Mode:",travel_mode_counts1)
# Out:
# Distinct outcomes for Travel Mode: ['car' 'na' 'uber' 'taxi' 'lyft' 'subway' 'bus' 'bike']
# Number of distinct outcomes for Travel Mode: 8
# Counts for each distinct outcome in Travel Mode: na        396
# car       260
# taxi      189
# uber       80
# lyft       41
# bike       15
# bus        11
# subway      8
# Name: Travel Mode, dtype: int64

# %%
# Find and print unique Sentiment
unique_Sentiment1 = df1['Sentiment'].unique()
print("Distinct outcomes for Sentiment:", unique_Sentiment1)

# Count and print the number of unique Sentiment
number_of_distinct_Sentiment1 = df1['Sentiment'].nunique()
print("Number of distinct outcomes for Sentiment:", number_of_distinct_Sentiment1)

# Print the counts of each Sentiment
Sentiment_counts1 = df1['Sentiment'].value_counts()
print("Counts for each distinct outcome in Sentiment:",Sentiment_counts1)
# Out:
# Distinct outcomes for Sentiment: ['positive' nan 'negative' 'neutral' 'na']
# Number of distinct outcomes for Sentiment: 4
# Counts for each distinct outcome in Sentiment: negative    378
# positive    179
# neutral      46
# na            1
# Name: Sentiment, dtype: int64

# %%
# Create a contingency table
contingency_table1 = pd.crosstab(df1['Travel Mode'], df1['Sentiment'])

# Display the contingency table
print(contingency_table1)
# Out:
# Sentiment    na  negative  neutral  positive
# Travel Mode
# bike          0         9        1         5
# bus           0         6        2         3
# car           0       197        8        55
# lyft          0        29        1        11
# subway        0         6        1         1
# taxi          1        80       24        84
# uber          0        51        9        20

# %%
# Normalize the contingency table by travel mode to get proportions
proportion_table1 = pd.crosstab(df1['Travel Mode'], df1['Sentiment'], normalize='index')

# Display the normalized contingency table as percentages
print(proportion_table1)
# Out:
# Sentiment          na  negative   neutral  positive
# Travel Mode
# bike         0.000000  0.600000  0.066667  0.333333
# bus          0.000000  0.545455  0.181818  0.272727
# car          0.000000  0.757692  0.030769  0.211538
# lyft         0.000000  0.707317  0.024390  0.268293
# subway       0.000000  0.750000  0.125000  0.125000
# taxi         0.005291  0.423280  0.126984  0.444444
# uber         0.000000  0.637500  0.112500  0.250000

# %% [markdown]
# #### (2) DF2: 177000_177999

# %%
# Find and print unique travel modes
unique_travel_modes2 = df2['Travel Mode'].unique()
print("Distinct outcomes for Travel Mode:", unique_travel_modes2)

# Count and print the number of unique travel modes
number_of_distinct_travel_modes2 = df2['Travel Mode'].nunique()
print("Number of distinct outcomes for Travel Mode:", number_of_distinct_travel_modes2)

# Print the counts of each travel mode
travel_mode_counts2 = df2['Travel Mode'].value_counts()
print("Counts for each distinct outcome in Travel Mode:",travel_mode_counts2)
# Out:
# Distinct outcomes for Travel Mode: ['na' 'subway' 'car' 'bike' 'taxi' 'bus']
# Number of distinct outcomes for Travel Mode: 6
# Counts for each distinct outcome in Travel Mode: car       828
# na        131
# subway     19
# bike       16
# taxi        4
# bus         2
# Name: Travel Mode, dtype: int64

# %%
# Find and print unique Sentiment
unique_Sentiment2 = df2['Sentiment'].unique()
print("Distinct outcomes for Sentiment:", unique_Sentiment2)

# Count and print the number of unique Sentiment
number_of_distinct_Sentiment2 = df2['Sentiment'].nunique()
print("Number of distinct outcomes for Sentiment:", number_of_distinct_Sentiment2)

# Print the counts of each Sentiment
Sentiment_counts2 = df2['Sentiment'].value_counts()
print("Counts for each distinct outcome in Sentiment:",Sentiment_counts2)
# Out:
# Distinct outcomes for Sentiment: [nan 'positive' 'neutral' 'negative' 'na']
# Number of distinct outcomes for Sentiment: 4
# Counts for each distinct outcome in Sentiment: negative    507
# positive    255
# neutral     106
# na            1
# Name: Sentiment, dtype: int64

# %%
# Create a contingency table
contingency_table2 = pd.crosstab(df2['Travel Mode'], df2['Sentiment'])

# Display the contingency table
print(contingency_table2)
# Out:
# Sentiment    na  negative  neutral  positive
# Travel Mode
# bike          0         9        1         6
# bus           0         1        0         1
# car           1       483      103       241
# subway        0        10        2         7
# taxi          0         4        0         0

# %%
# Normalize the contingency table by travel mode to get proportions
proportion_table2 = pd.crosstab(df2['Travel Mode'], df2['Sentiment'], normalize='index')

# Display the normalized contingency table as percentages
print(proportion_table2)
# Out:
# Sentiment          na  negative   neutral  positive
# Travel Mode
# bike         0.000000  0.562500  0.062500  0.375000
# bus          0.000000  0.500000  0.000000  0.500000
# car          0.001208  0.583333  0.124396  0.291063
# subway       0.000000  0.526316  0.105263  0.368421
# taxi         0.000000  1.000000  0.000000  0.000000

# %% [markdown]
# #### (3) DF1 & DF2

# %%
def calculate_rates(df):
    # Correctly filtering out both 'na' and 'NA'
    extraction_rate = len(df[~df['Travel Mode'].isin(['na', 'NA'])]) / len(df)
    satisfaction_rate = len(df[df['Sentiment'] == 'positive']) / len(df[~df['Travel Mode'].isin(['na', 'NA','NaN'])])
    self_verification_rate = len(df[df['Self Verification Result'] == 'correct']) / len(df)
    
    # Check if 'Cross Verification Result' exists in the DataFrame
    if 'Cross Verification Result' in df.columns:
        cross_verification_rate = len(df[df['Cross Verification Result'] == 'correct']) / len(df)
    else:
        cross_verification_rate = None  # Use None for DataFrames without cross-verification data

    return extraction_rate, satisfaction_rate, self_verification_rate, cross_verification_rate

# %%
# Calculate rates for each DataFrame
rates_df1 = calculate_rates(df1)
rates_df2 = calculate_rates(df2)
rates_df1_base = calculate_rates(df1_base)
rates_df2_base = calculate_rates(df2_base)

# Creating a list for each DataFrame rates to include in the summary
data_rates = [rates_df1_base, rates_df2_base, rates_df1, rates_df2]

# Creating the summary DataFrame
summary_df = pd.DataFrame(data_rates, columns=['Extraction Rate','Satisfaction Rate','Self-Verification Rate', 'Cross-Verification Rate'])
summary_df.index = ['baseline df1', 'baseline df2','final experiment df1', 'final experiment df2']

# Displaying the summary DataFrame
summary_df
# Out:
#                       Extraction Rate  Satisfaction Rate  \
# baseline df1                    1.000           0.018000
# baseline df2                    1.000           0.022000
# final experiment df1            0.604           0.296358
# final experiment df2            0.869           0.293441
#
#                       Self-Verification Rate  Cross-Verification Rate
# baseline df1                           0.990                      NaN
# baseline df2                           0.993                      NaN
# final experiment df1                   1.000                      1.0
# final experiment df2                   0.999                      1.0

# %% [markdown]
# ### 4. Data Visualization

# %% [markdown]
# #### (1) DF1: 60900_61899

# %%
explode_travel_mode1 = [0.1 if mode == travel_mode_counts1.idxmax() else 0 for mode in travel_mode_counts1.index]

# Plot for Travel Mode Distribution with explode for the largest piece
plt.figure(figsize=(8, 6))
plt.pie(travel_mode_counts1, labels=travel_mode_counts1.index, autopct='%1.1f%%', startangle=140, explode=explode_travel_mode1)
plt.title('Distribution of Travel Modes (Tweet 60900_61899)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(travel_mode_counts1.index, title="Travel Mode", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.tight_layout()  # Adjusts plot parameters for a tight fit
plt.show()

# %%
# count uber,lyft as taxi
# Copying the 'Travel Mode' series to avoid changing df1
travel_mode_series = df1['Travel Mode'].replace(['uber', 'lyft'], 'taxi').copy()

# Now, calculate the counts for the modified series
travel_mode_counts1_mod = travel_mode_series.value_counts()

# Generate the explode list for the modified counts
explode_travel_mode1_mod = [0.1 if mode == travel_mode_counts1_mod.idxmax() else 0 for mode in travel_mode_counts1_mod.index]

# Plot for Travel Mode Distribution with modified counts
plt.figure(figsize=(8, 6))
plt.pie(travel_mode_counts1_mod, labels=travel_mode_counts1_mod.index, autopct='%1.1f%%', startangle=140, explode=explode_travel_mode1_mod)
plt.title('Distribution of Travel Modes-taxi adjusted (Tweet 60900_61899)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(travel_mode_counts1_mod.index, title="Travel Mode", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.tight_layout()  # Adjusts plot parameters for a tight fit
plt.show()

# %%
explode_sentiment1 = [0.1 if sentiment == Sentiment_counts1.idxmax() else 0 for sentiment in Sentiment_counts1.index]
# Plot for Sentiment Distribution with explode for the largest piece
plt.figure(figsize=(8, 6))
plt.pie(Sentiment_counts1, labels=Sentiment_counts1.index, autopct='%1.1f%%', startangle=140, explode=explode_sentiment1)
plt.title('Distribution of Sentiments (Tweet 60900_61899)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(Sentiment_counts1.index, title="Sentiment", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.tight_layout()  # Adjusts plot parameters for a tight fit
plt.show()

# %%
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(contingency_table1, annot=True, fmt="d", cmap="YlGnBu", cbar=True)
plt.title('Heatmap of Travel Mode vs Sentiment (Tweet 60900_61899)')
plt.xlabel('Sentiment')
plt.ylabel('Travel Mode')
plt.show()

# %%
# Plot the heatmap of proportions
plt.figure(figsize=(10, 8))
sns.heatmap(proportion_table1, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('Proportion Heatmap of Travel Mode vs Sentiment (Tweet 60900_61899)')
plt.xlabel('Sentiment')
plt.ylabel('Travel Mode')
plt.show()

# %%
# Plot a stacked bar chart of proportions
proportion_table1.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 7))
plt.title('Proportion of Sentiment Within Each Travel Mode (Tweet 60900_61899)')
plt.xlabel('Travel Mode')
plt.ylabel('Proportion')
plt.legend(title='Sentiment', loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
# length & sentiment
#Calculate tweet length
df1['Tweet Length'] = df1['Tweet'].apply(len)

# Create a boxplot of tweet lengths by sentiment
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sentiment', y='Tweet Length', data=df1, palette='Set3')
plt.title('Boxplot of Tweet Lengths by Sentiment (Tweet 60900_61899)')
plt.xlabel('Sentiment')
plt.ylabel('Tweet Length')
plt.show()

# %% [markdown]
# #### (1) DF2: 177000_177999

# %%
explode_travel_mode2 = [0.1 if mode == travel_mode_counts2.idxmax() else 0 for mode in travel_mode_counts2.index]

# Plot for Travel Mode Distribution with explode for the largest piece
plt.figure(figsize=(8, 6))
plt.pie(travel_mode_counts2, labels=travel_mode_counts2.index, autopct='%1.1f%%', startangle=140, explode=explode_travel_mode2)
plt.title('Distribution of Travel Modes (Tweet 177000_177999)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(travel_mode_counts2.index, title="Travel Mode", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.tight_layout()  # Adjusts plot parameters for a tight fit
plt.show()

# %%
explode_sentiment2 = [0.1 if sentiment == Sentiment_counts2.idxmax() else 0 for sentiment in Sentiment_counts2.index]
# Plot for Sentiment Distribution with explode for the largest piece
plt.figure(figsize=(8, 6))
plt.pie(Sentiment_counts1, labels=Sentiment_counts2.index, autopct='%1.1f%%', startangle=140, explode=explode_sentiment2)
plt.title('Distribution of Sentiments (Tweet 177000_177999)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(Sentiment_counts2.index, title="Sentiment", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.tight_layout()  # Adjusts plot parameters for a tight fit
plt.show()

# %%
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(contingency_table2, annot=True, fmt="d", cmap="YlGnBu", cbar=True)
plt.title('Heatmap of Travel Mode vs Sentiment (Tweet 177000_177999)')
plt.xlabel('Sentiment')
plt.ylabel('Travel Mode')
plt.show()

# %%
# Plot the heatmap of proportions
plt.figure(figsize=(10, 8))
sns.heatmap(proportion_table2, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('Proportion Heatmap of Travel Mode vs Sentiment (Tweet 177000_177999)')
plt.xlabel('Sentiment')
plt.ylabel('Travel Mode')
plt.show()

# %%
# Plot a stacked bar chart of proportions
proportion_table2.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 7))
plt.title('Proportion of Sentiment Within Each Travel Mode (Tweet 177000_177999)')
plt.xlabel('Travel Mode')
plt.ylabel('Proportion')
plt.legend(title='Sentiment', loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
# length & sentiment
#Calculate tweet length
df2['Tweet Length'] = df2['Tweet'].apply(len)

# Create a boxplot of tweet lengths by sentiment
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sentiment', y='Tweet Length', data=df2, palette='Set3')
plt.title('Boxplot of Tweet Lengths by Sentiment (Tweet 177000_177999)')
plt.xlabel('Sentiment')
plt.ylabel('Tweet Length')
plt.show()

# %%
# Plotting
summary_df.plot(kind='bar', figsize=(10, 6))
plt.title('Comparison of Baseline Model & Final Experiment')
plt.legend(title='Rate', loc='upper left', bbox_to_anchor=(1, 1))
plt.ylabel('Rate')
plt.xlabel('Dataset')
plt.xticks(rotation=0)
plt.show()
